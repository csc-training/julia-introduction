# %% [markdown]
# ## SIMD Vectorization
# Does my code vectorize? Let's take a look.

# %%
function add(out, x, y)
    for i in 1:length(out)
        out[i] = x[i] + y[i]
    end
    return out
end
# Out:
# add (generic function with 1 method)

# %%
@code_llvm add(Vector{Float64}, Vector{Float64}, Vector{Float64})
# Out:
# define i8** @julia_add_63046(i8**, i8**, i8**) #0 !dbg !5 {
# top:
#   %3 = call i8**** @jl_get_ptls_states() #4
#   %4 = alloca [25 x i8**], align 8
#   %.sub = getelementptr inbounds [25 x i8**], [25 x i8**]* %4, i64 0, i64 0
#   %5 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 15
#   %6 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 18
#   %7 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 23
#   %8 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 21
#   %9 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 20
#   %10 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 2
#   %"#temp#" = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 3
#   %11 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 4
#   %12 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 5
#   %13 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 6
#   %14 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 7
#   %15 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 8
#   %16 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 9
#   %17 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 10
#   %18 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 11
#   %19 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 12
#   %20 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 13
#   %21 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 14
#   %22 = bitcast i8*** %5 to i8*
#   call void @llvm.memset.p0i8.i32(i8* %22, i8 0, i32 80, i32 8, i1 false)
#   %23 = bitcast [25 x i8**]* %4 to i64*
#   %24 = bitcast i8*** %10 to i8*
#   call void @llvm.memset.p0i8.i64(i8* %24, i8 0, i64 96, i32 8, i1 false)
#   store i64 46, i64* %23, align 8
#   %25 = bitcast i8**** %3 to i64*
#   %26 = load i64, i64* %25, align 8
#   %27 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 1
#   %28 = bitcast i8*** %27 to i64*
#   store i64 %26, i64* %28, align 8
#   store i8*** %.sub, i8**** %3, align 8
#   store i8** null, i8*** %21, align 8
#   %29 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 17
#   %30 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 16
#   %31 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 22
#   %32 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 24
#   %33 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 19
#   store i8** inttoptr (i64 4465473416 to i8**), i8*** %9, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %8, align 8
#   %34 = call i8** @jl_apply_generic(i8*** %9, i32 2)
#   store i8** %34, i8*** %29, align 8
#   store i8** inttoptr (i64 4465460824 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4464394384 to i8**), i8*** %30, align 8
#   %35 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %35, i8*** %10, align 8
#   store i8** inttoptr (i64 4466247440 to i8**), i8*** %6, align 8
#   store i8** %35, i8*** %33, align 8
#   %36 = call i8** @jl_apply_generic(i8*** %6, i32 2)
#   store i8** %36, i8*** %"#temp#", align 8
#   %37 = bitcast i8*** %"#temp#" to i64*
#   %38 = bitcast i8*** %29 to i64*
#   %39 = bitcast i8*** %9 to i64*
#   %40 = ptrtoint i8** %36 to i64
#   br label %L3
#
# L3:                                               ; preds = %cont10, %top
#   %41 = phi i64 [ %.pre, %cont10 ], [ %40, %top ]
#   store i64 %41, i64* %38, align 8
#   store i8** inttoptr (i64 4479144712 to i8**), i8*** %5, align 8
#   store i8** %35, i8*** %30, align 8
#   %42 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %42, i8*** %33, align 8
#   store i8** inttoptr (i64 4479143928 to i8**), i8*** %6, align 8
#   %43 = call i8** @jl_apply_generic(i8*** %6, i32 2)
#   store i8** %43, i8*** %11, align 8
#   %44 = getelementptr i8*, i8** %43, i64 -1
#   %45 = bitcast i8** %44 to i64*
#   %46 = load i64, i64* %45, align 8
#   %47 = and i64 %46, -16
#   %48 = inttoptr i64 %47 to i8**
#   %49 = icmp eq i8** %48, inttoptr (i64 4464265680 to i8**)
#   br i1 %49, label %pass, label %fail
#
# fail:                                             ; preds = %L3
#   call void @jl_type_error_rt(i8* inttoptr (i64 140547513618480 to i8*), i8* inttoptr (i64 140547513406304 to i8*), i8** inttoptr (i64 4464265680 to i8**), i8** %43)
#   unreachable
#
# pass:                                             ; preds = %L3
#   %50 = icmp eq i8** %43, inttoptr (i64 4464431200 to i8**)
#   br i1 %50, label %L29, label %if
#
# if:                                               ; preds = %pass
#   %51 = load i64, i64* %37, align 8
#   store i64 %51, i64* %39, align 8
#   store i8** inttoptr (i64 4465467480 to i8**), i8*** %6, align 8
#   store i8** %35, i8*** %33, align 8
#   %52 = call i8** @jl_apply_generic(i8*** %6, i32 3)
#   store i8** %52, i8*** %12, align 8
#   store i8** %52, i8*** %7, align 8
#   store i8** inttoptr (i64 4464394384 to i8**), i8*** %32, align 8
#   %53 = call i8** @jl_f_getfield(i8** null, i8*** %7, i32 2)
#   store i8** %53, i8*** %13, align 8
#   store i8** %52, i8*** %8, align 8
#   store i8** inttoptr (i64 4464394448 to i8**), i8*** %31, align 8
#   %54 = call i8** @jl_f_getfield(i8** null, i8*** %8, i32 2)
#   store i8** %54, i8*** %"#temp#", align 8
#   %55 = call i8** inttoptr (i64 4384023088 to i8** (i8**, i64)*)(i8** inttoptr (i64 4789815856 to i8**), i64 1)
#   store i8** %55, i8*** %14, align 8
#   store i8** %55, i8*** %15, align 8
#   store i8** %53, i8*** %29, align 8
#   store i8** inttoptr (i64 4464282072 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %30, align 8
#   %56 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %56, i8*** %16, align 8
#   %57 = getelementptr i8*, i8** %56, i64 -1
#   %58 = bitcast i8** %57 to i64*
#   %59 = load i64, i64* %58, align 8
#   %60 = and i64 %59, -16
#   %61 = inttoptr i64 %60 to i8**
#   %62 = icmp eq i8** %61, inttoptr (i64 4465068304 to i8**)
#   br i1 %62, label %pass3, label %fail2
#
# L29:                                              ; preds = %pass
#   %63 = load i64, i64* %28, align 8
#   store i64 %63, i64* %25, align 8
#   ret i8** inttoptr (i64 4465068304 to i8**)
#
# fail2:                                            ; preds = %if
#   call void @jl_type_error_rt(i8* inttoptr (i64 140547513618480 to i8*), i8* inttoptr (i64 140547513375776 to i8*), i8** inttoptr (i64 4465068304 to i8**), i8** %56)
#   unreachable
#
# pass3:                                            ; preds = %if
#   %64 = getelementptr inbounds i8*, i8** %55, i64 2
#   %65 = bitcast i8** %64 to i16*
#   %66 = load i16, i16* %65, align 2
#   %67 = and i16 %66, 3
#   %68 = icmp eq i16 %67, 3
#   br i1 %68, label %array_owned, label %merge_own
#
# array_owned:                                      ; preds = %pass3
#   %69 = getelementptr i8*, i8** %55, i64 5
#   %70 = bitcast i8** %69 to i8***
#   %71 = load i8**, i8*** %70, align 8
#   br label %merge_own
#
# merge_own:                                        ; preds = %array_owned, %pass3
#   %72 = phi i8** [ %55, %pass3 ], [ %71, %array_owned ]
#   %73 = bitcast i8** %55 to i8****
#   %74 = load i8***, i8**** %73, align 8
#   %75 = getelementptr i8*, i8** %72, i64 -1
#   %76 = bitcast i8** %75 to i64*
#   %77 = load i64, i64* %76, align 8
#   %78 = and i64 %77, 3
#   %79 = icmp eq i64 %78, 3
#   %80 = and i64 %59, 1
#   %81 = icmp eq i64 %80, 0
#   %or.cond = and i1 %79, %81
#   br i1 %or.cond, label %wb_trigger, label %cont
#
# wb_trigger:                                       ; preds = %merge_own
#   call void @jl_gc_queue_root(i8** %72)
#   br label %cont
#
# cont:                                             ; preds = %wb_trigger, %merge_own
#   store i8** %56, i8*** %74, align 8
#   %82 = call i8** inttoptr (i64 4384023088 to i8** (i8**, i64)*)(i8** inttoptr (i64 4789815856 to i8**), i64 1)
#   store i8** %82, i8*** %17, align 8
#   store i8** %82, i8*** %18, align 8
#   store i8** %53, i8*** %29, align 8
#   store i8** inttoptr (i64 4464282072 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %30, align 8
#   %83 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %83, i8*** %19, align 8
#   %84 = getelementptr i8*, i8** %83, i64 -1
#   %85 = bitcast i8** %84 to i64*
#   %86 = load i64, i64* %85, align 8
#   %87 = and i64 %86, -16
#   %88 = inttoptr i64 %87 to i8**
#   %89 = icmp eq i8** %88, inttoptr (i64 4465068304 to i8**)
#   br i1 %89, label %pass5, label %fail4
#
# fail4:                                            ; preds = %cont
#   call void @jl_type_error_rt(i8* inttoptr (i64 140547513618480 to i8*), i8* inttoptr (i64 140547513375776 to i8*), i8** inttoptr (i64 4465068304 to i8**), i8** %83)
#   unreachable
#
# pass5:                                            ; preds = %cont
#   %90 = getelementptr inbounds i8*, i8** %82, i64 2
#   %91 = bitcast i8** %90 to i16*
#   %92 = load i16, i16* %91, align 2
#   %93 = and i16 %92, 3
#   %94 = icmp eq i16 %93, 3
#   br i1 %94, label %array_owned6, label %merge_own7
#
# array_owned6:                                     ; preds = %pass5
#   %95 = getelementptr i8*, i8** %82, i64 5
#   %96 = bitcast i8** %95 to i8***
#   %97 = load i8**, i8*** %96, align 8
#   br label %merge_own7
#
# merge_own7:                                       ; preds = %array_owned6, %pass5
#   %98 = phi i8** [ %82, %pass5 ], [ %97, %array_owned6 ]
#   %99 = bitcast i8** %82 to i8****
#   %100 = load i8***, i8**** %99, align 8
#   %101 = getelementptr i8*, i8** %98, i64 -1
#   %102 = bitcast i8** %101 to i64*
#   %103 = load i64, i64* %102, align 8
#   %104 = and i64 %103, 3
#   %105 = icmp eq i64 %104, 3
#   %106 = and i64 %86, 1
#   %107 = icmp eq i64 %106, 0
#   %or.cond25 = and i1 %105, %107
#   br i1 %or.cond25, label %wb_trigger9, label %cont10
#
# wb_trigger9:                                      ; preds = %merge_own7
#   call void @jl_gc_queue_root(i8** %98)
#   br label %cont10
#
# cont10:                                           ; preds = %wb_trigger9, %merge_own7
#   store i8** %83, i8*** %100, align 8
#   store i8** %55, i8*** %20, align 8
#   store i8** %82, i8*** %21, align 8
#   %108 = call i8** @"julia_+_63047"(i8** %55, i8** %82)
#   store i8** %108, i8*** %29, align 8
#   store i8** %53, i8*** %6, align 8
#   store i8** inttoptr (i64 4464293864 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %30, align 8
#   %109 = call i8** @jl_apply_generic(i8*** %5, i32 4)
#   %.pre = load i64, i64* %37, align 8
#   br label %L3
# }

# %% [markdown]
# ## @inbounds
# Adding `@inbounds` removes the bound-checks and gives LLVM the opportunity to auto-vectorize this function.

# %%
function add2(out, x, y)
    @inbounds for i in 1:length(out)
        out[i] = x[i] + y[i]
    end
    return out
end
# Out:
# add2 (generic function with 1 method)

# %%
@code_llvm add2(Vector{Float64}, Vector{Float64}, Vector{Float64})
# Out:
# define i8** @julia_add2_63060(i8**, i8**, i8**) #0 !dbg !5 {
# top:
#   %3 = call i8**** @jl_get_ptls_states() #4
#   %4 = alloca [25 x i8**], align 8
#   %.sub = getelementptr inbounds [25 x i8**], [25 x i8**]* %4, i64 0, i64 0
#   %5 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 15
#   %6 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 18
#   %7 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 23
#   %8 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 21
#   %9 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 20
#   %10 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 2
#   %"#temp#" = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 3
#   %11 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 4
#   %12 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 5
#   %13 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 6
#   %14 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 7
#   %15 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 8
#   %16 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 9
#   %17 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 10
#   %18 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 11
#   %19 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 12
#   %20 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 13
#   %21 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 14
#   %22 = bitcast i8*** %5 to i8*
#   call void @llvm.memset.p0i8.i32(i8* %22, i8 0, i32 80, i32 8, i1 false)
#   %23 = bitcast [25 x i8**]* %4 to i64*
#   %24 = bitcast i8*** %10 to i8*
#   call void @llvm.memset.p0i8.i64(i8* %24, i8 0, i64 96, i32 8, i1 false)
#   store i64 46, i64* %23, align 8
#   %25 = bitcast i8**** %3 to i64*
#   %26 = load i64, i64* %25, align 8
#   %27 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 1
#   %28 = bitcast i8*** %27 to i64*
#   store i64 %26, i64* %28, align 8
#   store i8*** %.sub, i8**** %3, align 8
#   store i8** null, i8*** %21, align 8
#   %29 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 17
#   %30 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 16
#   %31 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 19
#   %32 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 22
#   %33 = getelementptr [25 x i8**], [25 x i8**]* %4, i64 0, i64 24
#   store i8** inttoptr (i64 4465473416 to i8**), i8*** %6, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %31, align 8
#   %34 = call i8** @jl_apply_generic(i8*** %6, i32 2)
#   store i8** %34, i8*** %29, align 8
#   store i8** inttoptr (i64 4465460824 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4464394384 to i8**), i8*** %30, align 8
#   %35 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %35, i8*** %10, align 8
#   store i8** inttoptr (i64 4466247440 to i8**), i8*** %9, align 8
#   store i8** %35, i8*** %8, align 8
#   %36 = call i8** @jl_apply_generic(i8*** %9, i32 2)
#   store i8** %36, i8*** %"#temp#", align 8
#   %37 = bitcast i8*** %"#temp#" to i64*
#   %38 = bitcast i8*** %29 to i64*
#   %39 = ptrtoint i8** %36 to i64
#   br label %L4
#
# L4:                                               ; preds = %cont10, %top
#   %40 = phi i64 [ %.pre, %cont10 ], [ %39, %top ]
#   store i64 %40, i64* %38, align 8
#   store i8** inttoptr (i64 4479144712 to i8**), i8*** %5, align 8
#   store i8** %35, i8*** %30, align 8
#   %41 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %41, i8*** %31, align 8
#   store i8** inttoptr (i64 4479143928 to i8**), i8*** %6, align 8
#   %42 = call i8** @jl_apply_generic(i8*** %6, i32 2)
#   store i8** %42, i8*** %11, align 8
#   %43 = getelementptr i8*, i8** %42, i64 -1
#   %44 = bitcast i8** %43 to i64*
#   %45 = load i64, i64* %44, align 8
#   %46 = and i64 %45, -16
#   %47 = inttoptr i64 %46 to i8**
#   %48 = icmp eq i8** %47, inttoptr (i64 4464265680 to i8**)
#   br i1 %48, label %pass, label %fail
#
# fail:                                             ; preds = %L4
#   call void @jl_type_error_rt(i8* inttoptr (i64 140547492318544 to i8*), i8* inttoptr (i64 140547513406304 to i8*), i8** inttoptr (i64 4464265680 to i8**), i8** %42)
#   unreachable
#
# pass:                                             ; preds = %L4
#   %49 = icmp eq i8** %42, inttoptr (i64 4464431200 to i8**)
#   br i1 %49, label %L30, label %if
#
# if:                                               ; preds = %pass
#   %50 = load i64, i64* %37, align 8
#   store i64 %50, i64* %38, align 8
#   store i8** inttoptr (i64 4465467480 to i8**), i8*** %5, align 8
#   store i8** %35, i8*** %30, align 8
#   %51 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %51, i8*** %12, align 8
#   store i8** %51, i8*** %7, align 8
#   store i8** inttoptr (i64 4464394384 to i8**), i8*** %33, align 8
#   %52 = call i8** @jl_f_getfield(i8** null, i8*** %7, i32 2)
#   store i8** %52, i8*** %13, align 8
#   store i8** %51, i8*** %8, align 8
#   store i8** inttoptr (i64 4464394448 to i8**), i8*** %32, align 8
#   %53 = call i8** @jl_f_getfield(i8** null, i8*** %8, i32 2)
#   store i8** %53, i8*** %"#temp#", align 8
#   %54 = call i8** inttoptr (i64 4384023088 to i8** (i8**, i64)*)(i8** inttoptr (i64 4789815856 to i8**), i64 1)
#   store i8** %54, i8*** %14, align 8
#   store i8** %54, i8*** %15, align 8
#   store i8** %52, i8*** %9, align 8
#   store i8** inttoptr (i64 4464282072 to i8**), i8*** %6, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %31, align 8
#   %55 = call i8** @jl_apply_generic(i8*** %6, i32 3)
#   store i8** %55, i8*** %16, align 8
#   %56 = getelementptr i8*, i8** %55, i64 -1
#   %57 = bitcast i8** %56 to i64*
#   %58 = load i64, i64* %57, align 8
#   %59 = and i64 %58, -16
#   %60 = inttoptr i64 %59 to i8**
#   %61 = icmp eq i8** %60, inttoptr (i64 4465068304 to i8**)
#   br i1 %61, label %pass3, label %fail2
#
# L30:                                              ; preds = %pass
#   %62 = load i64, i64* %28, align 8
#   store i64 %62, i64* %25, align 8
#   ret i8** inttoptr (i64 4465068304 to i8**)
#
# fail2:                                            ; preds = %if
#   call void @jl_type_error_rt(i8* inttoptr (i64 140547492318544 to i8*), i8* inttoptr (i64 140547513375776 to i8*), i8** inttoptr (i64 4465068304 to i8**), i8** %55)
#   unreachable
#
# pass3:                                            ; preds = %if
#   %63 = getelementptr inbounds i8*, i8** %54, i64 2
#   %64 = bitcast i8** %63 to i16*
#   %65 = load i16, i16* %64, align 2
#   %66 = and i16 %65, 3
#   %67 = icmp eq i16 %66, 3
#   br i1 %67, label %array_owned, label %merge_own
#
# array_owned:                                      ; preds = %pass3
#   %68 = getelementptr i8*, i8** %54, i64 5
#   %69 = bitcast i8** %68 to i8***
#   %70 = load i8**, i8*** %69, align 8
#   br label %merge_own
#
# merge_own:                                        ; preds = %array_owned, %pass3
#   %71 = phi i8** [ %54, %pass3 ], [ %70, %array_owned ]
#   %72 = bitcast i8** %54 to i8****
#   %73 = load i8***, i8**** %72, align 8
#   %74 = getelementptr i8*, i8** %71, i64 -1
#   %75 = bitcast i8** %74 to i64*
#   %76 = load i64, i64* %75, align 8
#   %77 = and i64 %76, 3
#   %78 = icmp eq i64 %77, 3
#   %79 = and i64 %58, 1
#   %80 = icmp eq i64 %79, 0
#   %or.cond = and i1 %78, %80
#   br i1 %or.cond, label %wb_trigger, label %cont
#
# wb_trigger:                                       ; preds = %merge_own
#   call void @jl_gc_queue_root(i8** %71)
#   br label %cont
#
# cont:                                             ; preds = %wb_trigger, %merge_own
#   store i8** %55, i8*** %73, align 8
#   %81 = call i8** inttoptr (i64 4384023088 to i8** (i8**, i64)*)(i8** inttoptr (i64 4789815856 to i8**), i64 1)
#   store i8** %81, i8*** %17, align 8
#   store i8** %81, i8*** %18, align 8
#   store i8** %52, i8*** %29, align 8
#   store i8** inttoptr (i64 4464282072 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %30, align 8
#   %82 = call i8** @jl_apply_generic(i8*** %5, i32 3)
#   store i8** %82, i8*** %19, align 8
#   %83 = getelementptr i8*, i8** %82, i64 -1
#   %84 = bitcast i8** %83 to i64*
#   %85 = load i64, i64* %84, align 8
#   %86 = and i64 %85, -16
#   %87 = inttoptr i64 %86 to i8**
#   %88 = icmp eq i8** %87, inttoptr (i64 4465068304 to i8**)
#   br i1 %88, label %pass5, label %fail4
#
# fail4:                                            ; preds = %cont
#   call void @jl_type_error_rt(i8* inttoptr (i64 140547492318544 to i8*), i8* inttoptr (i64 140547513375776 to i8*), i8** inttoptr (i64 4465068304 to i8**), i8** %82)
#   unreachable
#
# pass5:                                            ; preds = %cont
#   %89 = getelementptr inbounds i8*, i8** %81, i64 2
#   %90 = bitcast i8** %89 to i16*
#   %91 = load i16, i16* %90, align 2
#   %92 = and i16 %91, 3
#   %93 = icmp eq i16 %92, 3
#   br i1 %93, label %array_owned6, label %merge_own7
#
# array_owned6:                                     ; preds = %pass5
#   %94 = getelementptr i8*, i8** %81, i64 5
#   %95 = bitcast i8** %94 to i8***
#   %96 = load i8**, i8*** %95, align 8
#   br label %merge_own7
#
# merge_own7:                                       ; preds = %array_owned6, %pass5
#   %97 = phi i8** [ %81, %pass5 ], [ %96, %array_owned6 ]
#   %98 = bitcast i8** %81 to i8****
#   %99 = load i8***, i8**** %98, align 8
#   %100 = getelementptr i8*, i8** %97, i64 -1
#   %101 = bitcast i8** %100 to i64*
#   %102 = load i64, i64* %101, align 8
#   %103 = and i64 %102, 3
#   %104 = icmp eq i64 %103, 3
#   %105 = and i64 %85, 1
#   %106 = icmp eq i64 %105, 0
#   %or.cond25 = and i1 %104, %106
#   br i1 %or.cond25, label %wb_trigger9, label %cont10
#
# wb_trigger9:                                      ; preds = %merge_own7
#   call void @jl_gc_queue_root(i8** %97)
#   br label %cont10
#
# cont10:                                           ; preds = %wb_trigger9, %merge_own7
#   store i8** %82, i8*** %99, align 8
#   store i8** %54, i8*** %20, align 8
#   store i8** %81, i8*** %21, align 8
#   %107 = call i8** @"julia_+_63047"(i8** %54, i8** %81)
#   store i8** %107, i8*** %29, align 8
#   store i8** %52, i8*** %6, align 8
#   store i8** inttoptr (i64 4464293864 to i8**), i8*** %5, align 8
#   store i8** inttoptr (i64 4465068304 to i8**), i8*** %30, align 8
#   %108 = call i8** @jl_apply_generic(i8*** %5, i32 4)
#   %.pre = load i64, i64* %37, align 8
#   br label %L4
# }

# %% [markdown]
# ## SIMD.jl
# Other option is to use explicit SIMD vectorization instructions. The [SIMD.jl](https://github.com/eschnett/SIMD.jl) library gives you correct data types for this.

# %% [markdown]
# ## Additionally:
# Look [here](https://slides.com/valentinchuravy/julia-parallelism) for a lecture about levels of parallelism in Julia.
#
# The syntactic loop fusion is discussed [here](https://julialang.org/blog/2017/01/moredots).
